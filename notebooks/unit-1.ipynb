# %% [markdown]
# # OpenCourses.AI Colab version
#
# This notebook belongs to **Fundamentos de Transformers** and was published as a public Colab-ready artifact.
#
# Colab is an external free execution option with variable resources. Run the setup cell before executing the rest of the notebook.

# %%
# OpenCourses.AI Colab setup
import os, pathlib, subprocess, sys
REPO_URL = "https://github.com/opencourses-ai-colab/opencourse-fundamentos-de-transformers-d9d23ccb.git"
BRANCH = "main"
TARGET = pathlib.Path("/content/opencourses/opencourse-fundamentos-de-transformers-d9d23ccb")
TARGET.parent.mkdir(parents=True, exist_ok=True)
if not TARGET.exists():
    print('Downloading the course resources...')
    subprocess.run(["git", "clone", "--depth", "1", "--branch", BRANCH, REPO_URL, str(TARGET)], check=True)
else:
    print('Using the existing course folder; your local changes are preserved.')
os.environ['COURSE_ROOT'] = str(TARGET)
os.environ['ASSETS_DIR'] = str(TARGET / 'assets')
src_dir = TARGET / 'src'
if src_dir.is_dir() and str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))
notebooks_dir = TARGET / 'notebooks'
if notebooks_dir.exists():
    os.chdir(notebooks_dir)
requirements = TARGET / 'requirements.txt'
if requirements.exists() and requirements.read_text(encoding='utf8').strip():
    print('Checking the course Python dependencies...')
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', str(requirements)], check=True)
try:
    from google.colab import output as colab_output
except ImportError:
    pass
else:
    try:
        colab_output.enable_custom_widget_manager()
    except Exception as error:
        print(f'Widget support could not be enabled: {error}')
print(f'COURSE_ROOT={TARGET}')
print('Setup complete. Run the remaining notebook cells from top to bottom.')

# %% [markdown]
# <div style="border-bottom: 2px solid #1f2a44; padding-bottom: 14px; margin-bottom: 22px;">
#   <div style="display: flex; align-items: center; justify-content: space-between; gap: 24px;">
#     <div style="text-align: center; flex: 1; min-width: 260px;">
#       <div style="font-size: 14px; letter-spacing: 0.04em; text-transform: uppercase; color: #5b6472;">Fundamentos de Transformers</div>
#       <div style="font-size: 15px; font-weight: 700; color: #667085; margin-top: 6px;">Notebook 00</div>
#       <div style="font-size: 26px; font-weight: 700; color: #1f2a44; margin-top: 2px;">Presentación del curso</div>
#       <div style="font-size: 14px; color: #5b6472; margin-top: 8px;">Curso abierto</div>
#     </div>
#   </div>
# </div>
#
# <div style="display: flex; justify-content: space-between; gap: 16px; color: #3f4754; font-size: 14px; margin-bottom: 20px; flex-wrap: wrap;">
#   <div><strong>Ruta:</strong> atención, geometría y modelos autoregresivos desde cero</div>
#   <div><strong>Inicio:</strong> audio, alcance y mapa del curso</div>
# </div>

# %% [markdown]
# ## presentación
#
# <audio controls style="width: 100%; margin: 8px 0 18px 0;">
#   <source src="https://raw.githubusercontent.com/opencourses-ai-colab/opencourse-fundamentos-de-transformers-d9d23ccb/main/assets/audio/presentacion_curso.mp3" type="audio/mpeg">
#   Su navegador no puede reproducir el audio embebido.
# </audio>
#
# Esta presentación introduce la motivación del curso y el papel de los Transformers dentro del desarrollo reciente de la inteligencia artificial generativa.

# %% [markdown]
# ## Bienvenida
#
# Este curso estudia los fundamentos de los Transformers desde una perspectiva conceptual, geométrica y computacional. La ruta se concentra en comprender cómo una secuencia se transforma en representaciones internas, cómo opera la atención y cómo esos componentes se integran en un modelo autoregresivo pequeño.
#
# El punto de partida no es usar un sistema ya construido, sino abrir la arquitectura para entender sus piezas principales.

# %% [markdown]
# ## Por qué Transformers
#
# El estado actual de muchas tecnologías de inteligencia artificial depende de varias capas: infraestructura de cómputo, datos, optimización, estadística, matemáticas y arquitecturas capaces de escalar.
#
# Dentro de esa historia, el Transformer ocupa un lugar central porque hizo operativa la idea de autoatención: cada posición de una secuencia puede comparar su representación con otras posiciones y construir una nueva representación según las relaciones relevantes.
#
# Esa operación permitió modelar dependencias complejas de manera paralela y flexible, dentro de una ventana de contexto, sin depender únicamente de procesar la secuencia paso a paso.

# %% [markdown]
# ## Alcance
#
# El curso no es una introducción a ChatGPT, prompting, RAG, agentes ni ajuste de modelos grandes. Esos temas pertenecen a otra capa de uso y aplicación.
#
# Aquí el objetivo es entender los mecanismos fundamentales: tokens, embeddings, posición, formas tensoriales, atención, Q, K, V, self-attention, máscara causal, multi-head attention, bloque decoder, mini-GPT, entrenamiento autoregresivo, generación y límites.

# %% [markdown]
# ## Mapa de la ruta
#
# <div style="text-align: center; margin: 12px 0 18px 0;">
#   <img src="https://raw.githubusercontent.com/opencourses-ai-colab/opencourse-fundamentos-de-transformers-d9d23ccb/main/assets/figures/00_presentacion_del_curso.png" alt="Mapa de la ruta del curso" style="width: min(980px, 98%); height: auto; border: 1px solid #d0d7de; border-radius: 6px;">
# </div>
#
# | Tramo | Notebooks | Propósito |
# |---|---|---|
# | Presentación | 00 | Ubicar el curso, su motivación y su alcance. |
# | Secuencias y representación discreta | 01-05 | Formular el problema autoregresivo y preparar tokens, embeddings, posición y formas tensoriales. |
# | Atención y Q/K/V | 06-10 | Construir atención como mezcla, Q/K/V, self-attention, máscara causal y multi-head attention. |
# | Decoder y mini-GPT | 11-13 | Integrar residuales, LayerNorm, MLP, bloque decoder y un mini modelo autoregresivo. |
# | Entrenamiento, generación y cierre | 14-16 | Entrenar, generar, analizar límites y desarrollar el proyecto final. |

# %% [markdown]
# ## Forma de estudio
#
# Cada notebook técnico conecta una idea conceptual con una ecuación, una forma tensorial, código, visualizaciones e interpretación crítica.
#
# ```text
# concepto -> ecuación -> tensor -> código -> visualización -> interpretación crítica
# ```
#
# El criterio de avance no es memorizar nombres de capas, sino poder explicar qué objeto se está calculando, qué forma tiene, qué operación lo produce y qué límites tiene su interpretación.

# %% [markdown]
# ## Continuidad
#
# El contenido técnico inicia en:
#
# ```text
# notebooks/01_el_problema_de_modelar_secuencias.ipynb
# ```
#
# Allí se formula el lenguaje como secuencia discreta y se introduce la predicción autoregresiva del siguiente token.
